# %% [markdown]
# <a href="https://colab.research.google.com/github/trishaha/STAT108-Student-Success-Dashboard/blob/main/STAT108_2023_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df_31f = pd.read_csv("https://raw.githubusercontent.com/trishaha/STAT108-Student-Success-Dashboard/main/2024-04-15T1453_Grades-STAT_108_Sec31F%20-%202024-04-15T1453_Grades-STAT_108_Sec31F.csv")
df_13c = pd.read_csv("https://raw.githubusercontent.com/trishaha/STAT108-Student-Success-Dashboard/main/Hamilton%20Fall%202023.xlsx%20-%202024-04-16T1312_Grades-STAT_108.csv")
df_07b = pd.read_csv("https://raw.githubusercontent.com/trishaha/STAT108-Student-Success-Dashboard/main/Hamilton%20Spring%202023.xlsx%20-%20Hamilton%20Spring%202023.csv")

df_31f = df_31f.fillna(0)
df_13c = df_13c.fillna(0)
df_07b = df_07b.fillna(0)

df = pd.concat([df_31f, df_13c, df_07b], ignore_index=True)
df
# Out:
#      Student #                  Section  \
# 0          1.0  Fall 2023 - Section 31F
# 1          2.0  Fall 2023 - Section 31F
# 2          3.0  Fall 2023 - Section 31F
# 3          4.0  Fall 2023 - Section 31F
# 4          5.0  Fall 2023 - Section 31F
# ..         ...                      ...
# 361        NaN                      NaN
# 362        NaN                      NaN
# 363        NaN                      NaN
# 364        NaN                      NaN
# 365        NaN                      NaN
#
#      Final Exam - in COB-140A - NOT ACTIVITY!!! (774147)  Lec. 8/28 (796433)  \
# 0                                                171.0                   2.0
# 1                                                164.0                   2.0
# 2                                                137.0                   1.0
# 3                                                180.0                   2.0
# 4                                                  0.0                   2.0
# ...
